# %%
# Step 1: Import required libraries
import requests
import pandas as pd

# Step 2: Define the CoinGecko API endpoint
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 1000,
    'page': 1,
    'sparkline': 'false'
}

# Step 3: Make the GET request
response = requests.get(url, params=params)

# Step 4: Check the response status
if response.status_code == 200:
    crypto_data = response.json()
    print("✅ Crypto data fetched successfully!")
else:
    print(f"❌ Failed to fetch data. Status code: {response.status_code}")

# Step 5: Convert to pandas DataFrame
df = pd.DataFrame(crypto_data)

# Step 6: Display relevant columns
df_filtered = df[['id', 'symbol', 'name', 'current_price', 'market_cap', 'price_change_percentage_24h']]
df_filtered.columns = ['ID', 'Symbol', 'Name', 'Price (USD)', 'Market Cap', '24h % Change']
display(df_filtered)
# Out:
# ✅ Crypto data fetched successfully!
#                                       ID Symbol  \
# 0                                bitcoin    btc
# 1                               ethereum    eth
# 2                                 tether   usdt
# 3                                 ripple    xrp
# 4                            binancecoin    bnb
# ..                                   ...    ...
# 95                            paypal-usd  pyusd
# 96                             the-graph    grt
# 97  binance-bridged-usdc-bnb-smart-chain   usdc
# 98                                  wbnb   wbnb
# 99                       rocket-pool-eth   reth
#
#                                       Name   Price (USD)     Market Cap  \
# 0                                  Bitcoin  96356.000000  1913687368603
# 1                                 Ethereum   1828.080000   220713640816
# 2                                   Tether      1.000000   149218833259
# ...

# %%
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3       ripple    xrp       XRP
# 4  binancecoin    bnb       BNB
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       96356.00
# 1  https://coin-images.coingecko.com/coins/images...        1828.08
# 2  https://coin-images.coingecko.com/coins/images...           1.00
# 3  https://coin-images.coingecko.com/coins/images...           2.20
# 4  https://coin-images.coingecko.com/coins/images...         598.02
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1913687368603                1            1913687368603  2.152772e+10
# 1   220713640816                2             220713640816  1.013967e+10
# 2   149218833259                3             149218833259  1.700172e+10
# ...

# %%
df.shape
# Out:
# (100, 26)

# %%
# Step 1: Import libraries
import requests
import pandas as pd

# Step 2: Set the API URL and parameters (e.g., Kathmandu, Nepal)
url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 27.7172,
    "longitude": 85.3240,
    "hourly": "temperature_2m,relative_humidity_2m",
    "timezone": "auto"
}

# Step 3: Make the request
response = requests.get(url, params=params)

# Step 4: Process response
if response.status_code == 200:
    weather_data = response.json()
    print("✅ Weather data fetched successfully!")
else:
    print("❌ Failed to fetch weather data.")

# Step 5: Convert hourly data to DataFrame
df_weather = pd.DataFrame({
    "time": weather_data['hourly']['time'],
    "temperature": weather_data['hourly']['temperature_2m'],
    "humidity": weather_data['hourly']['relative_humidity_2m']
})

df_weather['time'] = pd.to_datetime(df_weather['time'])
display(df_weather.head())
# Out:
# ✅ Weather data fetched successfully!
#                  time  temperature  humidity
# 0 2025-05-03 00:00:00         15.8        87
# 1 2025-05-03 01:00:00         15.4        88
# 2 2025-05-03 02:00:00         15.0        89
# 3 2025-05-03 03:00:00         14.6        88
# 4 2025-05-03 04:00:00         14.1        88

# %%
# Step 1: Import libraries
import requests
import pandas as pd

# Step 2: Define the API URL and API key
api_key = "pub_84492ed15a72d8050cc04d9024663c1343133"  # Replace with your API key
url = f"https://newsdata.io/api/1/news?apikey={api_key}&country=np&language=en&category=technology"

# Step 3: Make the request
response = requests.get(url)

# Step 4: Check response and process
if response.status_code == 200:
    news_json = response.json()
    print("✅ News data fetched successfully!")
else:
    print("❌ Failed to fetch news data.")

# Step 5: Convert articles to DataFrame
news_articles = news_json.get("results", [])
df_news = pd.DataFrame(news_articles)[['title', 'link', 'pubDate', 'source_id']]
display(df_news.head())
# Out:
# ✅ News data fetched successfully!
#                                                title  \
# 0  From Exchange to Ecosystem Builder: MEXC Celeb...
# 1  Priority Pass Excellence Awards 2025 Winners R...
# 2  OSL & Ant Digital Technologies Forge Landmark ...
# 3    Australians more anxious ahead of 2025 election
# 4  MARRIOTT INTERNATIONAL AND CG HOSPITALITY ANNO...
#
#                                                 link              pubDate  \
# 0  https://www.prnewswire.com/apac/news-releases/...  2025-05-02 10:00:00
# 1  https://www.prnewswire.com/apac/news-releases/...  2025-05-02 07:55:00
# 2  https://www.prnewswire.com/apac/news-releases/...  2025-05-02 03:54:00
# 3  https://www.prnewswire.com/apac/news-releases/...  2025-05-02 02:43:00
# 4  https://www.prnewswire.com/apac/news-releases/...  2025-05-02 02:00:00
#
#          source_id
# 0  prnewswire_apac
# 1  prnewswire_apac
# 2  prnewswire_apac
# 3  prnewswire_apac
# 4  prnewswire_apac
