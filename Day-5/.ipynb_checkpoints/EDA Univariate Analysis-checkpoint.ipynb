# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#        hoa  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0        0          1  39.0    male  23.2             91      Yes         0
# 1        1          2  24.0    male  30.1             87       No         0
# 2        2          3   NaN    male  33.3             82      Yes         0
# 3        3          4   NaN    male  33.7             80       No         0
# 4        4          5   NaN    male  34.1            100       No         0
# ...    ...        ...   ...     ...   ...            ...      ...       ...
# 1335  1335       1336  44.0  female  35.5             88      Yes         0
# 1336  1336       1337  59.0  female  38.1            120       No         1
# 1337  1337       1338  30.0    male  34.5             91      Yes         3
# 1338  1338       1339  37.0    male  30.4            106       No         0
# 1339  1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# # EDA Univariate Analysis

# %% [markdown]
# ## Categorical Data (EDA)

# %%
cat_data = df.select_dtypes(include=object)
cat_data.head()
# Out:
#   gender diabetic smoker     region
# 0   male      Yes     No  southeast
# 1   male       No     No  southeast
# 2   male      Yes     No  southeast
# 3   male       No     No  northwest
# 4   male       No     No  northwest

# %% [markdown]
#  ### Now we got our Categorical Data Let's start the EDA

# %% [markdown]
# ## 1. Countplot

# %%
sns.countplot(df['gender'])
# Out:
# <Axes: xlabel='count', ylabel='gender'>

# %%
sns.countplot(df,x="diabetic")
# Out:
# <Axes: xlabel='diabetic', ylabel='count'>

# %%
data = sns.countplot(df,x="smoker")
data
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
data = sns.countplot(df,x="region")
data
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
df['region'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='region'>

# %%
df['diabetic'].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df['gender'].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df['smoker'].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
#  # Numerical Data (EDA)

# %%
num_data = df.select_dtypes(include=['int64','float64'])
num_data
# Out:
#       PatientID   age   bmi  bloodpressure  children     claim
# 0             1  39.0  23.2             91         0   1121.87
# 1             2  24.0  30.1             87         0   1131.51
# 2             3   NaN  33.3             82         0   1135.94
# 3             4   NaN  33.7             80         0   1136.40
# 4             5   NaN  34.1            100         0   1137.01
# ...         ...   ...   ...            ...       ...       ...
# 1335       1336  44.0  35.5             88         0  55135.40
# 1336       1337  59.0  38.1            120         1  58571.07
# 1337       1338  30.0  34.5             91         3  60021.40
# 1338       1339  37.0  30.4            106         0  62592.87
# 1339       1340  30.0  47.4            101         0  63770.43
#
# [1340 rows x 6 columns]

# %% [markdown]
# ### Now our data is ready to perfrom EDA

# %%
num_data
# Out:
#       PatientID   age   bmi  bloodpressure  children     claim
# 0             1  39.0  23.2             91         0   1121.87
# 1             2  24.0  30.1             87         0   1131.51
# 2             3   NaN  33.3             82         0   1135.94
# 3             4   NaN  33.7             80         0   1136.40
# 4             5   NaN  34.1            100         0   1137.01
# ...         ...   ...   ...            ...       ...       ...
# 1335       1336  44.0  35.5             88         0  55135.40
# 1336       1337  59.0  38.1            120         1  58571.07
# 1337       1338  30.0  34.5             91         3  60021.40
# 1338       1339  37.0  30.4            106         0  62592.87
# 1339       1340  30.0  47.4            101         0  63770.43
#
# [1340 rows x 6 columns]

# %% [markdown]
# ### 1. Histogram

# %%
plt.hist(df['age'])
# Out:
# (array([113., 123., 160., 156., 146., 179., 156., 127.,  76.,  99.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['bmi'])
# Out:
# (array([ 30., 130., 232., 319., 288., 195.,  96.,  33.,  14.,   3.]),
#  array([16.  , 19.71, 23.42, 27.13, 30.84, 34.55, 38.26, 41.97, 45.68,
#         49.39, 53.1 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 2. Distplot

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_10552\3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['bmi'])
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_10552\4168411822.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df['bloodpressure'])
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_10552\1935719.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bloodpressure'])
# <Axes: xlabel='bloodpressure', ylabel='Density'>

# %%
sns.distplot(df['claim'])
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_10552\2378324905.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['claim'])
# <Axes: xlabel='claim', ylabel='Density'>

# %% [markdown]
# ## 3. Boxplot

# %%
sns.boxplot(num_data['claim'])
# Out:
# <Axes: ylabel='claim'>

# %%
sns.boxplot(num_data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(num_data['bloodpressure'])
# Out:
# <Axes: ylabel='bloodpressure'>

# %%
sns.boxplot(num_data['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
df['age'].min()
# Out:
# np.float64(18.0)

# %%
df['age'].max()
# Out:
# np.float64(60.0)

# %%
df['age'].skew()
# Out:
# np.float64(0.11361133741072633)
